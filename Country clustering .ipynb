# %%
import numpy as np 
import pandas as pd
from sklearn.cluster import KMeans
import seaborn as sns 
import matplotlib.pyplot as plt
sns.set()

# %%
data = pd.read_csv("C:/Users/LENOVO/Downloads/Countries-exercise.csv")
data
# Out:
#              name   Longitude   Latitude
# 0           Aruba  -69.982677  12.520880
# 1     Afghanistan   66.004734  33.835231
# 2          Angola   17.537368 -12.293361
# 3        Anguilla  -63.064989  18.223959
# 4         Albania   20.049834  41.142450
# ..            ...         ...        ...
# 236         Samoa -172.164851 -13.753243
# 237         Yemen   47.586762  15.909280
# 238  South Africa   25.083901 -29.000341
# 239        Zambia   27.774759 -13.458242
# 240      Zimbabwe   29.851441 -19.004204
#
# [241 rows x 3 columns]

# %%
plt.scatter(data['Longitude'],data['Latitude'])
plt.xlim(-180,180)
plt.ylim(-90,90)
plt.xlabel('Longitude')
plt.ylabel('latitude')
plt.show()

# %%
x = data.iloc[:,1:3]
kmeans=KMeans(9)
kmeans.fit(x)
# Out:
# KMeans(n_clusters=9)

# %%
x
# Out:
#       Longitude   Latitude
# 0    -69.982677  12.520880
# 1     66.004734  33.835231
# 2     17.537368 -12.293361
# 3    -63.064989  18.223959
# 4     20.049834  41.142450
# ..          ...        ...
# 236 -172.164851 -13.753243
# 237   47.586762  15.909280
# 238   25.083901 -29.000341
# 239   27.774759 -13.458242
# 240   29.851441 -19.004204
#
# [241 rows x 2 columns]

# %%
identified_clusters  = kmeans.fit_predict(x)
identified_clusters
# Out:
# array([1, 3, 0, 1, 8, 8, 8, 3, 7, 3, 4, 0, 2, 0, 1, 2, 8, 3, 0, 8, 6, 6,
#        5, 8, 3, 1, 1, 8, 1, 8, 1, 1, 7, 7, 1, 5, 5, 0, 6, 8, 7, 5, 6, 6,
#        0, 6, 4, 1, 0, 6, 1, 1, 1, 1, 3, 3, 8, 8, 3, 1, 8, 1, 6, 1, 3, 3,
#        8, 8, 3, 8, 2, 7, 8, 8, 2, 6, 8, 3, 8, 6, 6, 6, 6, 6, 8, 1, 8, 1,
#        2, 1, 5, 0, 1, 8, 1, 8, 5, 8, 5, 5, 0, 8, 3, 3, 8, 3, 8, 1, 8, 3,
#        5, 3, 3, 0, 3, 5, 1, 1, 5, 8, 3, 5, 3, 6, 8, 1, 8, 5, 0, 8, 8, 8,
#        5, 1, 6, 8, 8, 0, 5, 1, 2, 8, 6, 8, 5, 8, 5, 2, 0, 6, 1, 0, 0, 5,
#        0, 2, 6, 2, 6, 1, 4, 8, 8, 5, 2, 2, 3, 3, 1, 4, 1, 5, 2, 2, 8, 1,
#        5, 8, 7, 3, 4, 3, 8, 5, 0, 6, 3, 3, 0, 6, 5, 7, 6, 2, 6, 1, 8, 3,
#        0, 1, 8, 6, 1, 8, 8, 8, 0, 1, 0, 3, 1, 6, 6, 5, 3, 3, 2, 4, 1, 8,
#        3, 5, 0, 0, 8, 7, 1, 3, 8, 1, 1, 1, 1, 5, 2, 4, 4, 3, 0, 0, 0])

# %%
data_with_clusters = data.copy()
data_with_clusters['clusters'] = identified_clusters
data_with_clusters
# Out:
#              name   Longitude   Latitude  clusters
# 0           Aruba  -69.982677  12.520880         1
# 1     Afghanistan   66.004734  33.835231         3
# 2          Angola   17.537368 -12.293361         0
# 3        Anguilla  -63.064989  18.223959         1
# 4         Albania   20.049834  41.142450         8
# ..            ...         ...        ...       ...
# 236         Samoa -172.164851 -13.753243         4
# 237         Yemen   47.586762  15.909280         3
# 238  South Africa   25.083901 -29.000341         0
# 239        Zambia   27.774759 -13.458242         0
# 240      Zimbabwe   29.851441 -19.004204         0
#
# [241 rows x 4 columns]

# %%
plt.scatter(data['Longitude'],data['Latitude'],c=data_with_clusters['clusters'],cmap='rainbow')
plt.xlim(-180,180)
plt.ylim(-90,90)
plt.xlabel('Longitude')
plt.ylabel('latitude')
plt.show()

# %% [markdown]
# ## WCSS

# %%
kmeans.inertia_
# Out:
# 84967.4172006829
