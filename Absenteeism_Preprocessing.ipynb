# %%
import pandas as pd
import numpy as np

# %%
raw_data=pd.read_csv('Absenteeism_data.csv')

# %%
raw_data
# Out:
#      ID  Reason for Absence        Date  Transportation Expense  \
# 0    11                  26  07/07/2015                     289
# 1    36                   0  14/07/2015                     118
# 2     3                  23  15/07/2015                     179
# 3     7                   7  16/07/2015                     279
# 4    11                  23  23/07/2015                     289
# ..   ..                 ...         ...                     ...
# 695  17                  10  23/05/2018                     179
# 696  28                   6  23/05/2018                     225
# 697  18                  10  24/05/2018                     330
# 698  25                  23  24/05/2018                     235
# 699  15                  28  31/05/2018                     291
#
#      Distance to Work  Age  Daily Work Load Average  Body Mass Index  \
# 0                  36   33                  239.554               30
# ...

# %%
data = raw_data.copy()
data =  data.drop('ID',axis=1)
data
# Out:
#      Reason for Absence        Date  Transportation Expense  Distance to Work  \
# 0                    26  07/07/2015                     289                36
# 1                     0  14/07/2015                     118                13
# 2                    23  15/07/2015                     179                51
# 3                     7  16/07/2015                     279                 5
# 4                    23  23/07/2015                     289                36
# ..                  ...         ...                     ...               ...
# 695                  10  23/05/2018                     179                22
# 696                   6  23/05/2018                     225                26
# 697                  10  24/05/2018                     330                16
# 698                  23  24/05/2018                     235                16
# 699                  28  31/05/2018                     291                31
#
# ...

# %%
data.columns
# Out:
# Index(['Reason for Absence', 'Date', 'Transportation Expense',
#        'Distance to Work', 'Age', 'Daily Work Load Average', 'Body Mass Index',
#        'Education', 'Children', 'Pets', 'Absenteeism Time in Hours'],
#       dtype='object')

# %%
data['Reason for Absence'].unique()
# Out:
# array([26,  0, 23,  7, 22, 19,  1, 11, 14, 21, 10, 13, 28, 18, 25, 24,  6,
#        27, 17,  8, 12,  5,  9, 15,  4,  3,  2, 16], dtype=int64)

# %%
# Create bins and labels
bins = [0, 14, 17, 21, 28]
labels = ['Reason_1', 'Reason_2', 'Reason_3', 'Reason_4']

# Cut the data into bins
data['Group'] = pd.cut(data['Reason for Absence'], bins=bins, labels= labels)

# Create dummy variables
data_dummies = pd.get_dummies(data['Group'])

# Concatenate the original dataframe with the dummies
data = pd.concat([data, data_dummies], axis=1)

# Drop the temporary 'Reason_Group' column
data.drop(columns=['Group'], inplace=True)

data
# Out:
#      Reason for Absence        Date  Transportation Expense  Distance to Work  \
# 0                    26  07/07/2015                     289                36
# 1                     0  14/07/2015                     118                13
# 2                    23  15/07/2015                     179                51
# 3                     7  16/07/2015                     279                 5
# 4                    23  23/07/2015                     289                36
# ..                  ...         ...                     ...               ...
# 695                  10  23/05/2018                     179                22
# 696                   6  23/05/2018                     225                26
# 697                  10  24/05/2018                     330                16
# 698                  23  24/05/2018                     235                16
# 699                  28  31/05/2018                     291                31
#
# ...

# %%
data_with_dummies = data.drop('Reason for Absence',axis=1)
data_with_dummies
# Out:
#            Date  Transportation Expense  Distance to Work  Age  \
# 0    07/07/2015                     289                36   33
# 1    14/07/2015                     118                13   50
# 2    15/07/2015                     179                51   38
# 3    16/07/2015                     279                 5   39
# 4    23/07/2015                     289                36   33
# ..          ...                     ...               ...  ...
# 695  23/05/2018                     179                22   40
# 696  23/05/2018                     225                26   28
# 697  24/05/2018                     330                16   28
# 698  24/05/2018                     235                16   32
# 699  31/05/2018                     291                31   40
#
#      Daily Work Load Average  Body Mass Index  Education  Children  Pets  \
# 0                    239.554               30          1         2     1
# ...

# %%
data_with_dummies['Reason_1'] = data_with_dummies['Reason_1'].astype(int)
data_with_dummies['Reason_2'] = data_with_dummies['Reason_2'].astype(int)
data_with_dummies['Reason_3'] = data_with_dummies['Reason_3'].astype(int)
data_with_dummies['Reason_4'] = data_with_dummies['Reason_4'].astype(int)

# %%
data_with_dummies
# Out:
#            Date  Transportation Expense  Distance to Work  Age  \
# 0    07/07/2015                     289                36   33
# 1    14/07/2015                     118                13   50
# 2    15/07/2015                     179                51   38
# 3    16/07/2015                     279                 5   39
# 4    23/07/2015                     289                36   33
# ..          ...                     ...               ...  ...
# 695  23/05/2018                     179                22   40
# 696  23/05/2018                     225                26   28
# 697  24/05/2018                     330                16   28
# 698  24/05/2018                     235                16   32
# 699  31/05/2018                     291                31   40
#
#      Daily Work Load Average  Body Mass Index  Education  Children  Pets  \
# 0                    239.554               30          1         2     1
# ...

# %%
data_with_dummies['Date'] = pd.to_datetime(data_with_dummies['Date'], format='%d/%m/%Y')

# %%
data_with_dummies['Month'] = data_with_dummies['Date'].dt.month
data_with_dummies['DayOfWeek'] = data_with_dummies['Date'].dt.dayofweek

# %%
data_with_dummies
# Out:
#           Date  Transportation Expense  Distance to Work  Age  \
# 0   2015-07-07                     289                36   33
# 1   2015-07-14                     118                13   50
# 2   2015-07-15                     179                51   38
# 3   2015-07-16                     279                 5   39
# 4   2015-07-23                     289                36   33
# ..         ...                     ...               ...  ...
# 695 2018-05-23                     179                22   40
# 696 2018-05-23                     225                26   28
# 697 2018-05-24                     330                16   28
# 698 2018-05-24                     235                16   32
# 699 2018-05-31                     291                31   40
#
#      Daily Work Load Average  Body Mass Index  Education  Children  Pets  \
# 0                    239.554               30          1         2     1
# ...

# %%
data_without_date = data_with_dummies.drop('Date',axis=1)

# %%
data_without_date
# Out:
#      Transportation Expense  Distance to Work  Age  Daily Work Load Average  \
# 0                       289                36   33                  239.554
# 1                       118                13   50                  239.554
# 2                       179                51   38                  239.554
# 3                       279                 5   39                  239.554
# 4                       289                36   33                  239.554
# ..                      ...               ...  ...                      ...
# 695                     179                22   40                  237.656
# 696                     225                26   28                  237.656
# 697                     330                16   28                  237.656
# 698                     235                16   32                  237.656
# 699                     291                31   40                  237.656
#
# ...

# %%
data_without_date['Education'] = data_without_date['Education'].apply(lambda x : 0 if x==1 else 1)

# %%
data_without_date
# Out:
#      Transportation Expense  Distance to Work  Age  Daily Work Load Average  \
# 0                       289                36   33                  239.554
# 1                       118                13   50                  239.554
# 2                       179                51   38                  239.554
# 3                       279                 5   39                  239.554
# 4                       289                36   33                  239.554
# ..                      ...               ...  ...                      ...
# 695                     179                22   40                  237.656
# 696                     225                26   28                  237.656
# 697                     330                16   28                  237.656
# 698                     235                16   32                  237.656
# 699                     291                31   40                  237.656
#
# ...

# %%
data_without_date.columns
# Out:
# Index(['Transportation Expense', 'Distance to Work', 'Age',
#        'Daily Work Load Average', 'Body Mass Index', 'Education', 'Children',
#        'Pets', 'Absenteeism Time in Hours', 'Reason_1', 'Reason_2', 'Reason_3',
#        'Reason_4', 'Month', 'DayOfWeek'],
#       dtype='object')

# %%
cols =  ['Reason_1', 'Reason_2','Reason_3', 'Reason_4', 'Month', 'DayOfWeek','Transportation Expense', 'Distance to Work', 'Age','Daily Work Load Average', 'Body Mass Index', 'Education', 'Children','Pets', 'Absenteeism Time in Hours']
data_without_date = data_without_date[cols]

# %%
data_without_date.to_csv('Df_preprocessed.csv')
