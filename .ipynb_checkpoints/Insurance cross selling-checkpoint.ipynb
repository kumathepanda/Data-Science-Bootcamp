# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import statsmodels.api as sm

# %%
raw_data = pd.read_csv("C:/Users/LENOVO/Desktop/train.csv")

# %%
raw_data.describe()
# Out:
#                  id           Age  Driving_License   Region_Code  \
# count  1.150480e+07  1.150480e+07     1.150480e+07  1.150480e+07
# mean   5.752398e+06  3.838356e+01     9.980220e-01  2.641869e+01
# std    3.321149e+06  1.499346e+01     4.443120e-02  1.299159e+01
# min    0.000000e+00  2.000000e+01     0.000000e+00  0.000000e+00
# 25%    2.876199e+06  2.400000e+01     1.000000e+00  1.500000e+01
# 50%    5.752398e+06  3.600000e+01     1.000000e+00  2.800000e+01
# 75%    8.628598e+06  4.900000e+01     1.000000e+00  3.500000e+01
# max    1.150480e+07  8.500000e+01     1.000000e+00  5.200000e+01
#
#        Previously_Insured  Annual_Premium  Policy_Sales_Channel       Vintage  \
# count        1.150480e+07    1.150480e+07          1.150480e+07  1.150480e+07
# mean         4.629966e-01    3.046137e+04          1.124254e+02  1.638977e+02
# std          4.986289e-01    1.645475e+04          5.403571e+01  7.997953e+01
# min          0.000000e+00    2.630000e+03          1.000000e+00  1.000000e+01
# 25%          0.000000e+00    2.527700e+04          2.900000e+01  9.900000e+01
# 50%          0.000000e+00    3.182400e+04          1.510000e+02  1.660000e+02
# 75%          1.000000e+00    3.945100e+04          1.520000e+02  2.320000e+02
# max          1.000000e+00    5.401650e+05          1.630000e+02  2.990000e+02
#
#            Response
# count  1.150480e+07
# mean   1.229973e-01
# std    3.284341e-01
# min    0.000000e+00
# 25%    0.000000e+00
# 50%    0.000000e+00
# 75%    0.000000e+00
# max    1.000000e+00

# %%
data  =  raw_data.copy()
data.head()
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   0    Male   21                1         35.0                   0
# 1   1    Male   43                1         28.0                   0
# 2   2  Female   25                1         14.0                   1
# 3   3  Female   35                1          1.0                   0
# 4   4  Female   36                1         15.0                   1
#
#   Vehicle_Age Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  \
# 0    1-2 Year            Yes         65101.0                 124.0      187
# 1   > 2 Years            Yes         58911.0                  26.0      288
# 2    < 1 Year             No         38043.0                 152.0      254
# 3    1-2 Year            Yes          2630.0                 156.0       76
# 4    1-2 Year             No         31951.0                 152.0      294
#
#    Response
# 0         0
# 1         1
# 2         0
# 3         0
# 4         0

# %%
from sklearn import preprocessing
data_dummies = data.copy()
data_dummies = pd.get_dummies(data['Vehicle_Age'], drop_first=False)
data_dummies
# Out:
#           1-2 Year  < 1 Year  > 2 Years
# 0             True     False      False
# 1            False     False       True
# 2            False      True      False
# 3             True     False      False
# 4             True     False      False
# ...            ...       ...        ...
# 11504793      True     False      False
# 11504794     False      True      False
# 11504795     False      True      False
# 11504796      True     False      False
# 11504797     False      True      False
#
# [11504798 rows x 3 columns]

# %%
data = pd.concat([data, data_dummies], axis=1)
data=data.drop(['Vehicle_Age'],axis=1)
data = data[data['Age'] >= 18]

# %%
cols = data.columns

# %%
sns.set(style='whitegrid')
sns.pairplot(
    data.sample(500)
)
# Out:
# C:\Users\LENOVO\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\LENOVO\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\LENOVO\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\LENOVO\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\LENOVO\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\LENOVO\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\LENOVO\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\LENOVO\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\LENOVO\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\LENOVO\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\LENOVO\Anaconda\Lib\site-packages\seaborn\_stats\counting.py:137: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
#   bin_edges = np.histogram_bin_edges(vals, bins, binrange, weight)
# C:\Users\LENOVO\Anaconda\Lib\site-packages\seaborn\_stats\counting.py:176: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
#   hist, edges = np.histogram(vals, **bin_kws, weights=weights, density=density)
# C:\Users\LENOVO\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\LENOVO\Anaconda\Lib\site-packages\seaborn\_stats\counting.py:137: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
#   bin_edges = np.histogram_bin_edges(vals, bins, binrange, weight)
# C:\Users\LENOVO\Anaconda\Lib\site-packages\seaborn\_stats\counting.py:176: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
#   hist, edges = np.histogram(vals, **bin_kws, weights=weights, density=density)
# C:\Users\LENOVO\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\LENOVO\Anaconda\Lib\site-packages\seaborn\_stats\counting.py:137: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
#   bin_edges = np.histogram_bin_edges(vals, bins, binrange, weight)
# C:\Users\LENOVO\Anaconda\Lib\site-packages\seaborn\_stats\counting.py:176: RuntimeWarning: Converting input from bool to <class 'numpy.uint8'> for compatibility.
#   hist, edges = np.histogram(vals, **bin_kws, weights=weights, density=density)

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data['Age'], kde=False, bins=10)
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\LENOVO\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(10, 6))
sns.histplot(data['Region_Code'], kde=False, bins=10)
plt.title('Distribution of Region Code')
plt.xlabel('Region Code')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\LENOVO\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
data['< 1 Year'].sum()
# Out:
# 5044145

# %%
data['> 2 Years'].sum()
# Out:
# 477975

# %%
data['Log_Age'] = np.log(data['Age'])
plt.figure(figsize=(10, 6))
sns.histplot(data['Log_Age'], kde=False, bins=10)
plt.title('Distribution of Log_Age')
plt.xlabel('Log_Age')
plt.ylabel('Frequency')
plt.show()
# Out:
# C:\Users\LENOVO\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
data['Age'] = raw_data['Age']
data.head()
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   0    Male   21                1         35.0                   0
# 1   1    Male   43                1         28.0                   0
# 2   2  Female   25                1         14.0                   1
# 3   3  Female   35                1          1.0                   0
# 4   4  Female   36                1         15.0                   1
#
#   Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  Response  \
# 0            Yes         65101.0                 124.0      187         0
# 1            Yes         58911.0                  26.0      288         1
# 2             No         38043.0                 152.0      254         0
# 3            Yes          2630.0                 156.0       76         0
# 4             No         31951.0                 152.0      294         0
#
#    1-2 Year  < 1 Year  > 2 Years   Log_Age
# 0      True     False      False  3.044522
# 1     False     False       True  3.761200
# 2     False      True      False  3.218876
# 3      True     False      False  3.555348
# 4      True     False      False  3.583519

# %%
#Checking If training data is Imbalanced
response_data = data['Response'].value_counts()
plt.figure(figsize=(6,6))
fig, ax = plt.subplots()
ax.pie(response_data, labels = [0,1])
ax.set_title('Checking Imbalance in Training Data Or Response')
# clearly we can see imbalance in the data set
# Out:
# Text(0.5, 1.0, 'Checking Imbalance in Training Data Or Response')

# %%
print(cols)
# Out:
# Index(['id', 'Gender', 'Age', 'Driving_License', 'Region_Code',
#        'Previously_Insured', 'Vehicle_Damage', 'Annual_Premium',
#        'Policy_Sales_Channel', 'Vintage', 'Response', '1-2 Year', '< 1 Year',
#        '> 2 Years'],
#       dtype='object')

# %%
data[['1-2 Year','< 1 Year','> 2 Years']] = data[['1-2 Year','< 1 Year','> 2 Years']].astype(int)
data['Gender'] = data['Gender'].map({'Male':1,'Female':0})
data['Vehicle_Damage'] = data['Vehicle_Damage'].map({'Yes':1,'No':0})
data.head()
# Out:
#    id  Gender  Age  Driving_License  Region_Code  Previously_Insured  \
# 0   0       1   21                1         35.0                   0
# 1   1       1   43                1         28.0                   0
# 2   2       0   25                1         14.0                   1
# 3   3       0   35                1          1.0                   0
# 4   4       0   36                1         15.0                   1
#
#    Vehicle_Damage  Annual_Premium  Policy_Sales_Channel  Vintage  Response  \
# 0               1         65101.0                 124.0      187         0
# 1               1         58911.0                  26.0      288         1
# 2               0         38043.0                 152.0      254         0
# 3               1          2630.0                 156.0       76         0
# 4               0         31951.0                 152.0      294         0
#
#    1-2 Year  < 1 Year  > 2 Years   Log_Age
# 0         1         0          0  3.044522
# 1         0         0          1  3.761200
# 2         0         1          0  3.218876
# 3         1         0          0  3.555348
# 4         1         0          0  3.583519

# %%
from imblearn.combine import SMOTEENN

# %%
smoteenn = SMOTEENN()
X_train = data[['id', 'Gender', 'Driving_License', 'Region_Code','Previously_Insured', 'Vehicle_Damage', 'Annual_Premium','Policy_Sales_Channel', 'Vintage', '1-2 Year', '< 1 Year','> 2 Years']]
y_train = data['Response']

X_test = data[['id', 'Gender', 'Driving_License', 'Region_Code','Previously_Insured', 'Vehicle_Damage', 'Annual_Premium','Policy_Sales_Channel', 'Vintage', '1-2 Year', '< 1 Year','> 2 Years']]

# %%
X_train_smoteenn, y_train_smoteenn = smoteenn.fit_resample(X_train, y_train)
print(y_train.value_counts())
print()
print(y_train_smoteenn.value_counts())
# Out:
# Response
# 0    10089739
# 1     1415059
# Name: count, dtype: int64
#
# Response
# 1    6926040
# 0    4804862
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_smoteenn)
data_scaled = scaler.fit_transform(data)
data_scaled
# Out:
# array([[-1.73205066,  0.92045115, -1.15940989, ..., -0.88359973,
#         -0.2081984 , -1.37792285],
#        [-1.73205036,  0.92045115,  0.30789673, ..., -0.88359973,
#          4.80311086,  0.48929553],
#        [-1.73205005, -1.08642376, -0.89262687, ...,  1.13173417,
#         -0.2081984 , -0.92366585],
#        ...,
#        [ 1.73205005, -1.08642376, -0.62584385, ...,  1.13173417,
#         -0.2081984 , -0.5369752 ],
#        [ 1.73205036, -1.08642376,  0.84146277, ..., -0.88359973,
#         -0.2081984 ,  0.93384001],
#        [ 1.73205066,  0.92045115, -0.89262687, ...,  1.13173417,
#         -0.2081984 , -0.92366585]])

# %%
# Split the data
x_train, x_test, y_train, y_test = train_test_split(X_train_scaled, y_train_smoteenn, test_size=0.3, random_state=42)

# Add a constant to the model (intercept)
x_train = sm.add_constant(x_train)
x_test = sm.add_constant(x_test)

# Fit the logistic regression model
reg_logit = sm.Logit(y_train, x_train)
results_logit = reg_logit.fit()

# Print summary of the model
print(results_logit.summary())
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.316863
#          Iterations: 35
# C:\Users\LENOVO\Anaconda\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:               Response   No. Observations:              8211631
# Model:                          Logit   Df Residuals:                  8211618
# Method:                           MLE   Df Model:                           12
# Date:                Fri, 12 Jul 2024   Pseudo R-squ.:                  0.5317
# Time:                        23:05:33   Log-Likelihood:            -2.6020e+06
# converged:                      False   LL-Null:                   -5.5564e+06
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          3.6907     42.049      0.088      0.930     -78.723      86.105
# x1             0.0026      0.001      2.412      0.016       0.000       0.005
# x2            -0.3318      0.001   -305.328      0.000      -0.334      -0.330
# x3             0.0365      0.001     41.199      0.000       0.035       0.038
# x4            -0.0026      0.001     -2.396      0.017      -0.005      -0.000
# x5            -2.5017      0.010   -243.446      0.000      -2.522      -2.482
# x6             0.6884      0.002    348.297      0.000       0.685       0.692
# x7             0.0830      0.001     75.210      0.000       0.081       0.085
# x8            -0.1140      0.001    -93.915      0.000      -0.116      -0.112
# x9            -0.0459      0.001    -42.642      0.000      -0.048      -0.044
# x10          -11.6973    105.371     -0.111      0.912    -218.221     194.826
# x11          -10.6646     88.909     -0.120      0.905    -184.923     163.594
# x12           -4.0426     34.946     -0.116      0.908     -72.535      64.450
# ==============================================================================
#
# Possibly complete quasi-separation: A fraction 0.20 of observations can be
# perfectly predicted. This might indicate that there is complete
# quasi-separation. In this case some parameters will not be identified.
