# %%
import pandas as pd
import numpy as np
import seaborn as sns
sns.set()
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("C:/Users/LENOVO/Downloads/real_estate_price_size_year (1).csv")
data.head()
# Out:
#         price     size  year
# 0  234314.144   643.09  2015
# 1  228581.528   656.22  2009
# 2  281626.336   487.29  2018
# 3  401255.608  1504.75  2015
# 4  458674.256  1275.46  2009

# %%
y = data['price']
x= data[['size','year']]
reg = LinearRegression()
reg.fit(x,y)
# Out:
# LinearRegression()

# %%
reg.score(x,y)
# Out:
# 0.7764803683276793

# %%
def adjusted_R_squared(x,y):
    R2 = reg.score(x,y)
    n = x.shape[0]
    p = x.shape[1]
    return (1-(1-R2)*(n-1)/(n-p-1))

# %%
adjusted_R_squared(x,y)
# Out:
# 0.77187171612825

# %%
reg.intercept_
# Out:
# -5772267.01746328

# %%
reg.coef_
# Out:
# array([ 227.70085401, 2916.78532684])

# %% [markdown]
# ## Feature Selection

# %%
from sklearn.feature_selection import f_regression
f_regression(x,y)
# Out:
# (array([285.92105192,   0.85525799]), array([8.12763222e-31, 3.57340758e-01]))

# %%
p_values = f_regression(x,y)[1]
p_values.round(3)
# Out:
# array([0.   , 0.357])

# %%
# YEAR is not significant

# %%
new_data  = pd.DataFrame(data=[[750,2009]],columns=[['size','year']])
new_data
# Out:
#   size  year
# 0  750  2009

# %%
reg.predict(new_data.values)
# Out:
# C:\Users\LENOVO\Anaconda\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([258330.34465995])

# %% [markdown]
# ## Creating a summary table

# %%
reg_summary = pd.DataFrame(data = ['size','year'],columns=['Feature'])
reg_summary
# Out:
#   Feature
# 0    size
# 1    year

# %%
reg_summary['coefficients']=reg.coef_
reg_summary['p_values'] = p_values

# %%
reg_summary
# Out:
#   Feature  coefficients      p_values
# 0    size    227.700854  8.127632e-31
# 1    year   2916.785327  3.573408e-01

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
scaler.fit(x)
# Out:
# StandardScaler()

# %%
x_scaled = scaler.transform(x)

# %%
x_scaled
# Out:
# array([[-0.70816415,  0.51006137],
#        [-0.66387316, -0.76509206],
#        [-1.23371919,  1.14763808],
#        [ 2.19844528,  0.51006137],
#        [ 1.42498884, -0.76509206],
#        [-0.937209  , -1.40266877],
#        [-0.95171405,  0.51006137],
#        [-0.78328682, -1.40266877],
#        [-0.57603328,  1.14763808],
#        [-0.53467702, -0.76509206],
#        [ 0.69939906, -0.76509206],
#        [ 3.33780001, -0.76509206],
#        [-0.53467702,  0.51006137],
#        [ 0.52699137,  1.14763808],
#        [ 1.51100715, -1.40266877],
#        [ 1.77668568, -1.40266877],
#        [-0.54810263,  1.14763808],
#        [-0.77276222, -1.40266877],
#        [-0.58004747, -1.40266877],
#        [ 0.58943055,  1.14763808],
#        [-0.78365788,  0.51006137],
#        [-1.02322731,  0.51006137],
#        [ 1.19557293,  0.51006137],
#        [-1.12884431,  0.51006137],
#        [-1.10378093, -0.76509206],
#        [ 0.84424715,  1.14763808],
#        [-0.95171405,  1.14763808],
# ...

# %%
reg_new = LinearRegression()
reg_new.fit(x_scaled,y)
# Out:
# LinearRegression()

# %%
new_data  = pd.DataFrame(data =[[750,2010]],columns = ['size','year'])
new_data
# Out:
#    size  year
# 0   750  2010

# %%
new_data_scaled = scaler.transform(new_data)

# %%
new_data_scaled
# Out:
# array([[-0.34752816, -0.55256648]])

# %%
reg_new.predict(new_data_scaled)
# Out:
# array([261247.12998678])

# %%
f_regression(x_scaled,y)
# Out:
# (array([285.92105192,   0.85525799]), array([8.12763222e-31, 3.57340758e-01]))

# %% [markdown]
# # from P value we reject 'year' feature

# %%
reg_newer = LinearRegression()
reg_newer.fit(x_scaled[:,0].reshape(-1,1),y)
# Out:
# LinearRegression()

# %%
reg_newer.predict(new_data_scaled[:,0].reshape(-1,1))
# Out:
# array([269296.65874718])
